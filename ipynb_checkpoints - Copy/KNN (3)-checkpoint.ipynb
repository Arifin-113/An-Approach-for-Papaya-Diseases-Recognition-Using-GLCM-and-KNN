# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix

# %%
path = r"C:\Users\Arifin\Downloads\papaya\Combined.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  1.734145  3.036386  2.198805  3.035556  0.882955  0.791500
# 1           1  1.520956  2.363153  1.397549  2.403998  0.952624  0.923539
# 2           2  3.571553  5.858547  3.863358  5.683906  0.875321  0.787117
# 3           3  1.180300  1.830111  1.141697  1.859715  0.931752  0.890712
# 4           4  1.540931  2.634064  1.678922  2.420730  0.919919  0.861302
#
#           6         7         8         9        10        11        12  \
# 0  0.838608  0.795025  0.573341  0.522803  0.546892  0.524873  0.834191
# 1  0.948591  0.922903  0.750079  0.739851  0.750343  0.739710  0.934104
# 2  0.842530  0.791819  0.523941  0.476633  0.505051  0.478834  0.841605
# 3  0.925612  0.891956  0.682465  0.665173  0.680382  0.665557  0.900281
# 4  0.903710  0.870088  0.537124  0.504991  0.527935  0.509307  0.919296
#
#          13        14        15                 16
# 0  0.709345  0.789736  0.709427  Fresh Papaya Leaf
# 1  0.897889  0.939451  0.896124  Fresh Papaya Leaf
# 2  0.739715  0.828408  0.747501  Fresh Papaya Leaf
# 3  0.845742  0.903535  0.843246  Fresh Papaya Leaf
# 4  0.862212  0.912176  0.873357  Fresh Papaya Leaf

# %%
df = df.rename(columns={'16': 'Class'})
features = df.drop('Class',axis=1)

# %%
df.info()
features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  300 non-null    int64
#  1   0           300 non-null    float64
#  2   1           300 non-null    float64
#  3   2           300 non-null    float64
#  4   3           300 non-null    float64
#  5   4           300 non-null    float64
#  6   5           300 non-null    float64
#  7   6           300 non-null    float64
#  8   7           300 non-null    float64
#  9   8           300 non-null    float64
#  10  9           300 non-null    float64
#  11  10          300 non-null    float64
#  12  11          300 non-null    float64
#  13  12          300 non-null    float64
#  14  13          300 non-null    float64
#  15  14          300 non-null    float64
#  16  15          300 non-null    float64
#  17  Class       300 non-null    object
# dtypes: float64(16), int64(1), object(1)
# memory usage: 42.3+ KB
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  1.734145  3.036386  2.198805  3.035556  0.882955  0.791500
# 1           1  1.520956  2.363153  1.397549  2.403998  0.952624  0.923539
# 2           2  3.571553  5.858547  3.863358  5.683906  0.875321  0.787117
# 3           3  1.180300  1.830111  1.141697  1.859715  0.931752  0.890712
# 4           4  1.540931  2.634064  1.678922  2.420730  0.919919  0.861302
#
#           6         7         8         9        10        11        12  \
# 0  0.838608  0.795025  0.573341  0.522803  0.546892  0.524873  0.834191
# 1  0.948591  0.922903  0.750079  0.739851  0.750343  0.739710  0.934104
# 2  0.842530  0.791819  0.523941  0.476633  0.505051  0.478834  0.841605
# 3  0.925612  0.891956  0.682465  0.665173  0.680382  0.665557  0.900281
# 4  0.903710  0.870088  0.537124  0.504991  0.527935  0.509307  0.919296
#
#          13        14        15
# 0  0.709345  0.789736  0.709427
# 1  0.897889  0.939451  0.896124
# 2  0.739715  0.828408  0.747501
# 3  0.845742  0.903535  0.843246
# 4  0.862212  0.912176  0.873357

# %%
from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler
  
scaler = MinMaxScaler()
  
scaler.fit(features)
features = scaler.transform(features)
  
df_feat = pd.DataFrame(features, columns = df.columns[:-1])
df_feat.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0    0.000000  0.144203  0.217655  0.209932  0.222391  0.682638  0.541379
# 1    0.014286  0.122049  0.158765  0.120959  0.166099  0.895694  0.869636
# 2    0.028571  0.335135  0.464519  0.394768  0.458445  0.659292  0.530483
# 3    0.042857  0.086651  0.112138  0.092549  0.117585  0.831866  0.788027
# 4    0.057143  0.124125  0.182462  0.152203  0.167590  0.795677  0.714910
#
#           6         7         8         9        10        11        12  \
# 0  0.509231  0.552194  0.369346  0.320230  0.328284  0.324568  0.509539
# 1  0.879372  0.871708  0.802423  0.807539  0.809200  0.806738  0.832093
# 2  0.522430  0.544183  0.248297  0.216571  0.229381  0.221240  0.533473
# 3  0.802038  0.794383  0.636742  0.639874  0.643828  0.640313  0.722899
# 4  0.728328  0.739745  0.280599  0.280238  0.283474  0.289632  0.784289
#
#          13        14        15
# 0  0.376964  0.469631  0.404330
# 1  0.815563  0.868931  0.815086
# 2  0.447612  0.572772  0.488097
# 3  0.694255  0.773142  0.698749
# 4  0.732570  0.796188  0.764995

# %%
from sklearn.model_selection import train_test_split
  
X_train, X_test, y_train, y_test = train_test_split(
      features, df['Class'], test_size = 0.36, random_state=42)
  
# Remember that we are trying to come up
# with a model to predict whether
# someone will TARGET CLASS or not.
# We'll start with k = 1.

from sklearn.neighbors import KNeighborsClassifier
  
knn = KNeighborsClassifier(n_neighbors = 1)
  
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

plot_confusion_matrix(knn, X_test, y_test)
plt.xticks(rotation = 90)
plt.show()

# Predictions and Evaluations
# Let's evaluate our KNN model !

# %%
from sklearn.metrics import classification_report  
print(classification_report(y_test, pred))
# Out:
#                    precision    recall  f1-score   support
#
# Fresh Papaya Leaf       0.86      0.76      0.81        25
# Papaya Black Spot       0.62      0.42      0.50        24
#  Papaya Leaf Curl       0.26      0.38      0.31        13
#   Papaya Ringspot       0.64      0.55      0.59        29
#    Powdery Mildew       0.19      0.29      0.23        17
#
#          accuracy                           0.51       108
#         macro avg       0.52      0.48      0.49       108
#      weighted avg       0.57      0.51      0.53       108

# %%
from sklearn import metrics
error_rate = []
scores = []

k=30
for i in range(1, k):
      
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
    y_predict = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test,y_predict))

# %%
plt.figure(figsize =(10, 6))
plt.plot(range(1, k), error_rate, color ='blue',
                linestyle ='dashed', marker ='o',
         markerfacecolor ='red', markersize = 10)
  
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
best_k=np.argmax(scores)
print("Accuracy for k = {} is {}".format(best_k,max(scores)))

plt.plot(np.arange(1,k),scores)
plt.title('Varition of accuracy with K value')
plt.xlabel('K values')
plt.ylabel('Accuracy')
# Out:
# Accuracy for k = 1 is 0.5185185185185185
# Text(0, 0.5, 'Accuracy')

# %%
knn = KNeighborsClassifier(n_neighbors = best_k)
  
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
from sklearn.metrics import classification_report  
print(classification_report(y_test, pred))
# Out:
#                    precision    recall  f1-score   support
#
# Fresh Papaya Leaf       0.86      0.76      0.81        25
# Papaya Black Spot       0.62      0.42      0.50        24
#  Papaya Leaf Curl       0.26      0.38      0.31        13
#   Papaya Ringspot       0.64      0.55      0.59        29
#    Powdery Mildew       0.19      0.29      0.23        17
#
#          accuracy                           0.51       108
#         macro avg       0.52      0.48      0.49       108
#      weighted avg       0.57      0.51      0.53       108
